# %%
import pandas as pd

lp = pd.read_csv('LOCAL_PEOPLE_2018.csv', index_col=[0,1,2])
lf = pd.read_csv('LONG_FORIEGNER_2018.csv', index_col=[0,1,2])
tf = pd.read_csv('TEMPORARY_FORIEGNER_2018.csv', index_col=[0,1,2])

lp
# Out:
#                              총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 기준일ID      시간대구분 자치구코드
# 2018-01-01 0     11110  256273.0604      6985.3617        3653.8530
#                  11140  176621.0532      5326.5131        2013.1455
#                  11170  293547.7332      7208.9039        3620.2581
#                  11200  322848.8585     11390.5507        4888.1312
#                  11215  398578.6493     11217.5545        5884.2123
# ...                             ...            ...              ...
# 2018-12-31 23    11620  524916.6579     13590.5873        6565.5665
#                  11650  514630.3683     16415.3162        9302.8094
#                  11680  686729.5029     19227.7038       12567.1378
#                  11710  748228.6015     28140.9981       14473.3287
#                  11740  516164.2769     19603.6127       10499.2087
#
#                         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 기준일ID      시간대구분 자치구코드
# ...

# %%
lp.drop(['총생활인구수', '요일'], axis=1, inplace=True)
lp
# Out:
#                         남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# 기준일ID      시간대구분 자치구코드
# 2018-01-01 0     11110      6985.3617        3653.8530        6572.5156
#                  11140      5326.5131        2013.1455        3188.3289
#                  11170      7208.9039        3620.2581        5842.7592
#                  11200     11390.5507        4888.1312        6877.0558
#                  11215     11217.5545        5884.2123       12406.6133
# ...                               ...              ...              ...
# 2018-12-31 23    11620     13590.5873        6565.5665       10200.2129
#                  11650     16415.3162        9302.8094       13656.2125
#                  11680     19227.7038       12567.1378       21313.5081
#                  11710     28140.9981       14473.3287       19229.8765
#                  11740     19603.6127       10499.2087       14170.3440
#
#                         남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# ...

# %%
lf.drop(['총생활인구수', '요일'], axis=1, inplace=True)
tf.drop('총생활인구수', axis=1, inplace=True)

# %%
people = pd.concat([lp, lf, tf], axis=1)
people
# Out:
#                         남자0세부터9세생활인구수  남자10세부터14세생활인구수  남자15세부터19세생활인구수  \
# 기준일ID      시간대구분 자치구코드
# 2018-01-01 0     11110      6985.3617        3653.8530        6572.5156
#                  11140      5326.5131        2013.1455        3188.3289
#                  11170      7208.9039        3620.2581        5842.7592
#                  11200     11390.5507        4888.1312        6877.0558
#                  11215     11217.5545        5884.2123       12406.6133
# ...                               ...              ...              ...
# 2018-12-31 23    11620     13590.5873        6565.5665       10200.2129
#                  11650     16415.3162        9302.8094       13656.2125
#                  11680     19227.7038       12567.1378       21313.5081
#                  11710     28140.9981       14473.3287       19229.8765
#                  11740     19603.6127       10499.2087       14170.3440
#
#                         남자20세부터24세생활인구수  남자25세부터29세생활인구수  남자30세부터34세생활인구수  \
# ...

# %%
people.drop(['남자0세부터9세생활인구수', '남자10세부터14세생활인구수', '여자0세부터9세생활인구수', '여자10세부터14세생활인구수'], axis=1, inplace=True)
people
# Out:
#                         남자15세부터19세생활인구수  남자20세부터24세생활인구수  남자25세부터29세생활인구수  \
# 기준일ID      시간대구분 자치구코드
# 2018-01-01 0     11110        6572.5156       12986.9063       13727.3330
#                  11140        3188.3289        7176.6213        8599.4203
#                  11170        5842.7592       11877.4543       15503.0524
#                  11200        6877.0558       11178.1725       13050.0497
#                  11215       12406.6133       18563.5674       18541.8660
# ...                                 ...              ...              ...
# 2018-12-31 23    11620       10200.2129       22375.6621       33873.0854
#                  11650       13656.2125       17593.0871       20018.6269
#                  11680       21313.5081       24308.6100       29680.7417
#                  11710       19229.8765       22680.2903       26807.7935
#                  11740       14170.3440       14708.4631       16431.6993
#
# ...

# %%
people.to_csv('2018생활인구.csv')
