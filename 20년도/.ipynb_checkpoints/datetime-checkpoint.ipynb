# %%
import pandas as pd

lp = pd.read_csv('LOCAL_PEOPLE_GU_2020.csv', encoding='cp949', index_col=False)
lf = pd.read_csv('LONG_FOREIGNER_GU_2020.csv', encoding='cp949', index_col=False)
tf = pd.read_csv('TEMP_FOREIGNER_GU_2020.csv', encoding='cp949', index_col=False)

lp
# Out:
#            기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20200101      0  11110  248283.0355      6496.6713        3519.7135
# 1       20200101      0  11140  187720.0184      4655.7791        1817.9263
# 2       20200101      0  11170  292640.2683      7594.5578        3783.8774
# 3       20200101      0  11200  333267.7444     12520.2471        5415.8134
# 4       20200101      0  11215  390059.2798     12015.7622        6462.2537
# ...          ...    ...    ...          ...            ...              ...
# 219595  20201231     23  11620  491876.3992     12042.7597        5878.9457
# 219596  20201231     23  11650  466368.7220     18594.7954       10289.7404
# 219597  20201231     23  11680  621348.1084     23088.1736       14923.8699
# 219598  20201231     23  11710  724883.1371     29325.6824       15030.9786
# 219599  20201231     23  11740  524891.9605     20670.5419       11726.7471
#
# ...

# %%
lp['기준일ID'] = lp['기준일ID'].astype('str')
lp['기준일ID']
# Out:
# 0         20200101
# 1         20200101
# 2         20200101
# 3         20200101
# 4         20200101
#             ...
# 219595    20201231
# 219596    20201231
# 219597    20201231
# 219598    20201231
# 219599    20201231
# Name: 기준일ID, Length: 219600, dtype: object

# %%
lp['기준일ID'] = pd.to_datetime(lp['기준일ID'])
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2020-01-01      0  11110  248283.0355      6496.6713        3519.7135
# 1      2020-01-01      0  11140  187720.0184      4655.7791        1817.9263
# 2      2020-01-01      0  11170  292640.2683      7594.5578        3783.8774
# 3      2020-01-01      0  11200  333267.7444     12520.2471        5415.8134
# 4      2020-01-01      0  11215  390059.2798     12015.7622        6462.2537
# ...           ...    ...    ...          ...            ...              ...
# 219595 2020-12-31     23  11620  491876.3992     12042.7597        5878.9457
# 219596 2020-12-31     23  11650  466368.7220     18594.7954       10289.7404
# 219597 2020-12-31     23  11680  621348.1084     23088.1736       14923.8699
# 219598 2020-12-31     23  11710  724883.1371     29325.6824       15030.9786
# 219599 2020-12-31     23  11740  524891.9605     20670.5419       11726.7471
#
# ...

# %%
lf['기준일ID'] = lf['기준일ID'].astype('str')
tf['기준일ID'] = tf['기준일ID'].astype('str')

lf['기준일ID'] = pd.to_datetime(lf['기준일ID'])
tf['기준일ID'] = pd.to_datetime(tf['기준일ID'])

# %%
lp['요일'] = lp['기준일ID'].dt.day_name()
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2020-01-01      0  11110  248283.0355      6496.6713        3519.7135
# 1      2020-01-01      0  11140  187720.0184      4655.7791        1817.9263
# 2      2020-01-01      0  11170  292640.2683      7594.5578        3783.8774
# 3      2020-01-01      0  11200  333267.7444     12520.2471        5415.8134
# 4      2020-01-01      0  11215  390059.2798     12015.7622        6462.2537
# ...           ...    ...    ...          ...            ...              ...
# 219595 2020-12-31     23  11620  491876.3992     12042.7597        5878.9457
# 219596 2020-12-31     23  11650  466368.7220     18594.7954       10289.7404
# 219597 2020-12-31     23  11680  621348.1084     23088.1736       14923.8699
# 219598 2020-12-31     23  11710  724883.1371     29325.6824       15030.9786
# 219599 2020-12-31     23  11740  524891.9605     20670.5419       11726.7471
#
# ...

# %%
lf['요일'] = lf['기준일ID'].dt.day_name()
tf['요일'] = tf['기준일ID'].dt.day_name()

# %%
lp.to_csv('LOCAL_PEOPLE_2020.csv', index=False)
lf.to_csv('LONG_FOREIGNER_2020.csv', index=False)
tf.to_csv('TEMPORARY_FOREIGNER_2020.csv', index=False)
