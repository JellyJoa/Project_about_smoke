# %%
import pandas as pd

lp = pd.read_csv('LOCAL_PEOPLE_GU_2019.csv', encoding='cp949', index_col=False)
lf = pd.read_csv('LONG_FOREIGNER_GU_2019.csv', encoding='cp949', index_col=False)
tf = pd.read_csv('TEMP_FOREIGNER_GU_2019.csv', encoding='cp949', index_col=False)

lp
# Out:
# C:\Users\sun\AppData\Local\Temp/ipykernel_18900/1000082992.py:3: ParserWarning: Length of header or names does not match length of data. This leads to a loss of data with index_col=False.
#   lp = pd.read_csv('LOCAL_PEOPLE_GU_2019.csv', encoding='cp949', index_col=False)
#            기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0       20190101      0  11110  247783.9476      6613.1044        3564.9470
# 1       20190101      0  11140  176516.2769      4735.9065        1857.9963
# 2       20190101      0  11170  287806.8492      7274.7405        3654.3768
# 3       20190101      0  11200  335106.5204     12278.8839        5306.1528
# 4       20190101      0  11215  399818.0269     12003.9916        6472.3827
# ...          ...    ...    ...          ...            ...              ...
# 211195  20191231     23  11620  512045.7410     13292.1313        6492.1774
# 211196  20191231     23  11650  507017.9562     17249.4614        9728.3280
# ...

# %%
lp['기준일ID'] = lp['기준일ID'].astype('str')
lp['기준일ID']
# Out:
# 0         20190101
# 1         20190101
# 2         20190101
# 3         20190101
# 4         20190101
#             ...
# 211195    20191231
# 211196    20191231
# 211197    20191231
# 211198    20191231
# 211199    20191231
# Name: 기준일ID, Length: 211200, dtype: object

# %%
lp['기준일ID'] = pd.to_datetime(lp['기준일ID'])
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2019-01-01      0  11110  247783.9476      6613.1044        3564.9470
# 1      2019-01-01      0  11140  176516.2769      4735.9065        1857.9963
# 2      2019-01-01      0  11170  287806.8492      7274.7405        3654.3768
# 3      2019-01-01      0  11200  335106.5204     12278.8839        5306.1528
# 4      2019-01-01      0  11215  399818.0269     12003.9916        6472.3827
# ...           ...    ...    ...          ...            ...              ...
# 211195 2019-12-31     23  11620  512045.7410     13292.1313        6492.1774
# 211196 2019-12-31     23  11650  507017.9562     17249.4614        9728.3280
# 211197 2019-12-31     23  11680  701730.1925     21768.6379       14313.7773
# 211198 2019-12-31     23  11710  776809.6518     29303.9813       15154.6352
# 211199 2019-12-31     23  11740  522271.9542     20543.7319       10960.7816
#
# ...

# %%
lf
# Out:
#            기준일ID  시간대구분  자치구코드      총생활인구수    중국인체류인구수  중국외외국인체류인구수
# 0       20190101      0  11110  17781.8892  11035.0773    6746.8132
# 1       20190101      0  11140  18002.6187  10923.9122    7078.7062
# 2       20190101      0  11170  27306.3659   5907.9073   21398.4597
# 3       20190101      0  11200  17225.0885  10136.1296    7088.9600
# 4       20190101      0  11215  26007.8091  20028.8521    5978.9571
# ...          ...    ...    ...         ...         ...          ...
# 211195  20191231     23  11620  23634.5007  18935.6050    4698.8936
# 211196  20191231     23  11650  12282.6724   4467.6237    7815.0499
# 211197  20191231     23  11680  23222.4219   9083.4988   14138.9230
# 211198  20191231     23  11710  21463.8273  10507.4467   10956.3839
# 211199  20191231     23  11740   9740.5395   7564.1576    2176.3825
#
# [211200 rows x 6 columns]

# %%
columns = lf.columns
columns
# Out:
# Index(['기준일ID', '시간대구분', '자치구코드', '총생활인구수', '중국인체류인구수', '중국외외국인체류인구수'], dtype='object')

# %%
tf.columns = columns
tf
# Out:
#            기준일ID  시간대구분  자치구코드      총생활인구수    중국인체류인구수  중국외외국인체류인구수
# 0       20190101      0  11110  18704.4856   8987.5825    9716.9030
# 1       20190101      0  11140  64870.1850  29424.3341   35445.8501
# 2       20190101      0  11170  14723.9941   4178.1144   10545.8802
# 3       20190101      0  11200   2164.7635    639.9332    1524.8298
# 4       20190101      0  11215   3008.5557   1409.8304    1598.7258
# ...          ...    ...    ...         ...         ...          ...
# 211195  20191231     23  11620   2116.0139   1074.1549    1041.8597
# 211196  20191231     23  11650   7739.7494   2227.6605    5512.0892
# 211197  20191231     23  11680  29055.5705  10486.5165   18569.0526
# 211198  20191231     23  11710  12454.2277   3885.5880    8568.6387
# 211199  20191231     23  11740   1286.9974    368.9743     918.0227
#
# [211200 rows x 6 columns]

# %%
lf['기준일ID'] = lf['기준일ID'].astype('str')
tf['기준일ID'] = tf['기준일ID'].astype('str')

lf['기준일ID'] = pd.to_datetime(lf['기준일ID'])
tf['기준일ID'] = pd.to_datetime(tf['기준일ID'])

# %%
lp['요일'] = lp['기준일ID'].dt.day_name()
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2019-01-01      0  11110  247783.9476      6613.1044        3564.9470
# 1      2019-01-01      0  11140  176516.2769      4735.9065        1857.9963
# 2      2019-01-01      0  11170  287806.8492      7274.7405        3654.3768
# 3      2019-01-01      0  11200  335106.5204     12278.8839        5306.1528
# 4      2019-01-01      0  11215  399818.0269     12003.9916        6472.3827
# ...           ...    ...    ...          ...            ...              ...
# 211195 2019-12-31     23  11620  512045.7410     13292.1313        6492.1774
# 211196 2019-12-31     23  11650  507017.9562     17249.4614        9728.3280
# 211197 2019-12-31     23  11680  701730.1925     21768.6379       14313.7773
# 211198 2019-12-31     23  11710  776809.6518     29303.9813       15154.6352
# 211199 2019-12-31     23  11740  522271.9542     20543.7319       10960.7816
#
# ...

# %%
lf['요일'] = lf['기준일ID'].dt.day_name()
tf['요일'] = tf['기준일ID'].dt.day_name()

# %%
lp.to_csv('LOCAL_PEOPLE_2019.csv', index=False)
lf.to_csv('LONG_FOREIGNER_2019.csv', index=False)
tf.to_csv('TEMPORARY_FOREIGNER_2019.csv', index=False)
