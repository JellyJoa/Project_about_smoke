# %%
import pandas as pd

lp = pd.read_csv('LOCAL_PEOPLE_2019.csv', index_col=False)
lf = pd.read_csv('LONG_FOREIGNER_2019.csv', index_col=False)
tf = pd.read_csv('TEMPORARY_FOREIGNER_2019.csv', index_col=False)

tf
# Out:
#              기준일ID  시간대구분  자치구코드      총생활인구수    중국인체류인구수  중국외외국인체류인구수       요일
# 0       2019-01-01      0  11110  18704.4856   8987.5825    9716.9030  Tuesday
# 1       2019-01-01      0  11140  64870.1850  29424.3341   35445.8501  Tuesday
# 2       2019-01-01      0  11170  14723.9941   4178.1144   10545.8802  Tuesday
# 3       2019-01-01      0  11200   2164.7635    639.9332    1524.8298  Tuesday
# 4       2019-01-01      0  11215   3008.5557   1409.8304    1598.7258  Tuesday
# ...            ...    ...    ...         ...         ...          ...      ...
# 211195  2019-12-31     23  11620   2116.0139   1074.1549    1041.8597  Tuesday
# 211196  2019-12-31     23  11650   7739.7494   2227.6605    5512.0892  Tuesday
# 211197  2019-12-31     23  11680  29055.5705  10486.5165   18569.0526  Tuesday
# 211198  2019-12-31     23  11710  12454.2277   3885.5880    8568.6387  Tuesday
# 211199  2019-12-31     23  11740   1286.9974    368.9743     918.0227  Tuesday
#
# ...

# %%
lp['기준일ID'] = pd.to_datetime(lp['기준일ID'])
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2019-01-01      0  11110  247783.9476      6613.1044        3564.9470
# 1      2019-01-01      0  11140  176516.2769      4735.9065        1857.9963
# 2      2019-01-01      0  11170  287806.8492      7274.7405        3654.3768
# 3      2019-01-01      0  11200  335106.5204     12278.8839        5306.1528
# 4      2019-01-01      0  11215  399818.0269     12003.9916        6472.3827
# ...           ...    ...    ...          ...            ...              ...
# 211195 2019-12-31     23  11620  512045.7410     13292.1313        6492.1774
# 211196 2019-12-31     23  11650  507017.9562     17249.4614        9728.3280
# 211197 2019-12-31     23  11680  701730.1925     21768.6379       14313.7773
# 211198 2019-12-31     23  11710  776809.6518     29303.9813       15154.6352
# 211199 2019-12-31     23  11740  522271.9542     20543.7319       10960.7816
#
# ...

# %%
lf['기준일ID'] = lf['기준일ID'].astype('str')
tf['기준일ID'] = tf['기준일ID'].astype('str')

lf['기준일ID'] = pd.to_datetime(lf['기준일ID'])
tf['기준일ID'] = pd.to_datetime(tf['기준일ID'])

# %%
lp['요일'] = lp['기준일ID'].dt.day_name()
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2019-01-01      0  11110  247783.9476      6613.1044        3564.9470
# 1      2019-01-01      0  11140  176516.2769      4735.9065        1857.9963
# 2      2019-01-01      0  11170  287806.8492      7274.7405        3654.3768
# 3      2019-01-01      0  11200  335106.5204     12278.8839        5306.1528
# 4      2019-01-01      0  11215  399818.0269     12003.9916        6472.3827
# ...           ...    ...    ...          ...            ...              ...
# 211195 2019-12-31     23  11620  512045.7410     13292.1313        6492.1774
# 211196 2019-12-31     23  11650  507017.9562     17249.4614        9728.3280
# 211197 2019-12-31     23  11680  701730.1925     21768.6379       14313.7773
# 211198 2019-12-31     23  11710  776809.6518     29303.9813       15154.6352
# 211199 2019-12-31     23  11740  522271.9542     20543.7319       10960.7816
#
# ...

# %%
lf['요일'] = lf['기준일ID'].dt.day_name()
tf['요일'] = tf['기준일ID'].dt.day_name()

# %%
lp['월'] = lp['기준일ID'].dt.strftime('%m')
lp
# Out:
#             기준일ID  시간대구분  자치구코드       총생활인구수  남자0세부터9세생활인구수  남자10세부터14세생활인구수  \
# 0      2019-01-01      0  11110  247783.9476      6613.1044        3564.9470
# 1      2019-01-01      0  11140  176516.2769      4735.9065        1857.9963
# 2      2019-01-01      0  11170  287806.8492      7274.7405        3654.3768
# 3      2019-01-01      0  11200  335106.5204     12278.8839        5306.1528
# 4      2019-01-01      0  11215  399818.0269     12003.9916        6472.3827
# ...           ...    ...    ...          ...            ...              ...
# 211195 2019-12-31     23  11620  512045.7410     13292.1313        6492.1774
# 211196 2019-12-31     23  11650  507017.9562     17249.4614        9728.3280
# 211197 2019-12-31     23  11680  701730.1925     21768.6379       14313.7773
# 211198 2019-12-31     23  11710  776809.6518     29303.9813       15154.6352
# 211199 2019-12-31     23  11740  522271.9542     20543.7319       10960.7816
#
# ...

# %%
lf['월'] = lf['기준일ID'].dt.strftime('%m')
tf['월'] = tf['기준일ID'].dt.strftime('%m')

# %%
lp.to_csv('LOCAL_PEOPLE_2019-1.csv', index=False)
lf.to_csv('LONG_FOREIGNER_2019-1.csv', index=False)
tf.to_csv('TEMPORARY_FOREIGNER_2019-1.csv', index=False)
